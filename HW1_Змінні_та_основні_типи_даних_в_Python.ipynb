# %% [markdown]
# ## HW1. Змінні та основні типи даних в Python
#
# **1. Створення змінних**
#
# Створіть змінні для особистої інформації (кожен пункт оцінюється в 0.5 бала):
# - `name` - ваше ім'я (рядок)
# - `age` - ваш вік (ціле число)
# - `height` - ваш зріст в метрах (дробове число)
# - `is_student` - чи є ви студентом (True/False)
#
# Виведіть кожну з цих змінних за допомогою функції `print()`.

# %%
name = "Olya"
age = 33
height = 1.61
is_student = False

# %%
print(f"My name is {name}")
print(f"My age is {age}")
print(f"My height is {height}")
print(f"Am I student: {is_student}")
# Out:
# My name is Olya
# My age is 33
# My height is 1.61
# Am I student: False

# %% [markdown]
# ---
#
# **2. Арифметичні операції**
#
# Створіть дві змінні: `var1` зі значенням 15, `var2` зі значенням 4.
#
# Обчисліть та виведіть (кожен пункт оцінюється в 0.5 бала):
# - Суму
# - Різницю
# - Добуток
# - Ділення
# - Цілочисельне ділення
# - Залишок від ділення
# - Піднесення до степеня

# %%
var1 = 15
var2 = 4
add = var1 + var2
diff = var1 - var2
prod = var1 * var2
div = var1 / var2
int_div = var1 // var2
rem = var1 % var2
exp = var1 ** var2

# %%
print(f"Sum is {add}")
print(f"Difference is {diff}")
print(f"Product is {prod}")
print(f"Division is {div}")
print(f"Integer division is {int_div}")
print(f"Remainder is {rem}")
print(f"Exponentiation is {exp}")
# Out:
# Sum is 19
# Difference is 11
# Product is 60
# Division is 3.75
# Integer division is 3
# Remainder is 3
# Exponentiation is 50625

# %% [markdown]
# ---
#
# **3. Робота з рядками**
#
# Створіть зміну `last_name`, яка містять ваше прізвище.
#
# Виконайте (кожен пункт оцінюється в 0.5 бала):
# - Об'єднайте значення змінних `name` та `last_name` через пробіл в один рядок і збережіть в нову змінну `full_name`
# - Виведіть `full_name` великими літерами
# - Виведіть `full_name` малими літерами
# - Виведіть довжину `full_name`
# - Виведіть фразу: "Мене звати [ім'я], мені [вік] років". Вік використайте зі змінної, створеної у вправі 1.

# %%
last_name = "Stulkivska"
full_name = f"{name} {last_name}"
print(f"Full name: {full_name}")
print(f"Full name upper: {full_name.upper()}")
print(f"Full name lower: {full_name.lower()}")
print(f"Full name length: {len(full_name)}")
print(f"My name is {name}, I am {age} years old")
# Out:
# Full name: Olya Stulkivska
# Full name upper: OLYA STULKIVSKA
# Full name lower: olya stulkivska
# Full name length: 15
# My name is Olya, I am 33 years old
